# %%
import pandas as pd
import numpy as np
import pickle as pkl
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
from matplotlib.backends.backend_pdf import PdfPages
pp = PdfPages('./pdfs/multipage_flower.pdf')

# %%
# Load saved dataframe 
base_df = pd.read_pickle('./pkls/df_flower_cleaned_and_ready.pkl')

# %% [markdown]
# ### Start with looking at Pearson correlations

# %%
correlations = base_df.corr()
mask = np.zeros_like(correlations, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
plt.figure(figsize=(8,7))
plt.title('Heat map of Pearson correlation metric')

cmap = sns.diverging_palette(220, 10, as_cmap=True)

corr_heat = sns.heatmap(correlations * 100, annot=True, fmt='.0f', mask=mask, cmap=cmap, cbar_kws={"shrink": .5})
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/flower_corr.pdf')
plt.close()

# %%
sns.distplot(base_df['Total THC'])
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/Total_THC.pdf')
plt.close()

# %%
sns.distplot(base_df['Delta-9-THC'])
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/Delta-9.pdf')
plt.close()

# %%
sns.distplot(base_df['THCA'])
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/THCA.pdf')
plt.close()

# %%
sns.distplot(base_df['Delta-8-THC'])
pp.savefig()
plt.close()

# %%
sns.distplot(base_df['THCV'])
pp.savefig()
plt.close()

# %%
sns.distplot(base_df['THCVA'])
pp.savefig()

# %%
sns.distplot(base_df['Total CBD'])
pp.savefig()

# %%
sns.distplot(base_df['CBD'])
pp.savefig()

# %%
sns.distplot(base_df['CBDA'])
pp.savefig()

# %%
sns.distplot(base_df['CBG'])
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/CBG.pdf')

# %%
sns.distplot(base_df['CBGA'])
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/CBGA.pdf')

# %%
sns.distplot(base_df['CBN'])
pp.savefig()

# %%
sns.distplot(base_df['CBDV'])
pp.savefig()

# %%
sns.distplot(base_df['CBDVA'])
pp.savefig()

# %%
plt.scatter(base_df['Total THC'], base_df['Total CBD'])
fig_size = [7,6]
plt.xlabel('Total THC [%]')
plt.ylabel('Total CBD [%]')
plt.title('Amount Total THC vs Total CBD, corr = -55')
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/Total_THC-Total_CBD.pdf')

# %%
plt.scatter(base_df['Total THC'], base_df['THCA'])
fig_size = [7,6]
plt.xlabel('Total THC [%]')
plt.ylabel('THCA [%]')
plt.title('Amount Total THC vs THCA, corr = 98')
pp.savefig()

# %%
plt.scatter(base_df['Total CBD'], base_df['CBDA'])
fig_size = [7,6]
plt.xlabel('Total CBD [%]')
plt.ylabel('CBDA [%]')
plt.title('Amount Total CBD vs CBDA, corr = 98')
pp.savefig()

# %%
plt.scatter(base_df['CBC'], base_df['CBD'])
fig_size = [7,6]
plt.xlabel('CBC [%]')
plt.ylabel('CBD [%]')
plt.title('Amount CBC vs CBD, corr = 72')
pp.savefig()

# %%
plt.scatter(base_df['Total THC'], base_df['CBDA'])
fig_size = [7,6]
plt.xlabel('Total THC [%]')
plt.ylabel('CBDA [%]')
plt.title('Amount Total THC vs CBDA, corr = -54')
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/Total_THC-CBDA.pdf')

# %%
plt.scatter(base_df['Total CBD'], base_df['THCA'])
fig_size = [7,6]
plt.xlabel('Total CBD [%]')
plt.ylabel('THCA [%]')
plt.title('Amount Total CBD vs THCA, corr = -53')
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/Total_CBD-THCA.pdf')

# %%
plt.scatter(base_df['THCA'], base_df['CBDA'])
fig_size = [7,6]
plt.xlabel('THCA [%]')
plt.ylabel('CBDA [%]')
plt.title('Amount THCA vs CBDA, corr = -51')
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/THCA-CBDA.pdf')

# %%
plt.scatter(base_df['Total CBD'], base_df['CBD'])
fig_size = [7,6]
plt.xlabel('Total CDB [%]')
plt.ylabel('CBD [%]')
plt.title('Amount Total CBD vs CBD, corr = 48')
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/Total_CBD-CBD.pdf')

# %%
plt.scatter(base_df['CBDA'], base_df['CBDVA'])
fig_size = [7,6]
plt.xlabel('CBDA [%]')
plt.ylabel('CBDVA [%]')
plt.title('Amount CBDA vs CBDVA, corr = 44')
pp.savefig()

# %%
plt.scatter(base_df['Total CBD'], base_df['CBDVA'])
fig_size = [7,6]
plt.xlabel('Total CBD [%]')
plt.ylabel('CBDVA [%]')
plt.title('Amount Total CBD vs CBDVA, corr = 43')
pp.savefig()

# %%
plt.scatter(base_df['Total CBD'], base_df['CBC'])
fig_size = [7,6]
plt.xlabel('Total CBD [%]')
plt.ylabel('CBC [%]')
plt.title('Amount Total CBD vs CBC, corr = 40')
pp.savefig()

# %%
plt.scatter(base_df['THCA'], base_df['CBGA'])
fig_size = [7,6]
plt.xlabel('THCA [%]')
plt.ylabel('CBGA [%]')
plt.title('Amount THCA vs CBGA, corr = 40')
pp.savefig()

# %%
plt.scatter(base_df['CBDA'], base_df['CBCA'])
fig_size = [7,6]
plt.xlabel('CBDA [%]')
plt.ylabel('CBCA [%]')
plt.title('Amount CBDA vs CBCA, corr = 40')
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/CBCA-CBDA.pdf')

# %%
plt.scatter(base_df['Total THC'], base_df['CBGA'])
fig_size = [7,6]
plt.xlabel('Total THC [%]')
plt.ylabel('CBGA [%]')
plt.title('Amount Total THC vs CBGA, corr = 39')
pp.savefig()

# %%
plt.scatter(base_df['Delta-9-THC'], base_df['CBN'])
fig_size = [7,6]
plt.xlabel('Delta-9-THC [%]')
plt.ylabel('CBN [%]')
plt.title('Amount Delta-9-THC vs CBN, corr = 34')
pp.savefig()

# %%
plt.scatter(base_df['THCA'], base_df['CBC'])
fig_size = [7,6]
plt.xlabel('THCA [%]')
plt.ylabel('CBC [%]')
plt.title('Amount THCA vs CBC, corr = -31')
pp.savefig()

# %%
plt.scatter(base_df['CBDA'], base_df['CBD'])
fig_size = [7,6]
plt.xlabel('CBDA [%]')
plt.ylabel('CBD [%]')
plt.title('Amount CBDA vs CBD, corr = 30')
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/CBD-CBDA.pdf')

# %%
plt.scatter(base_df['Total THC'], base_df['CBD'])
fig_size = [7,6]
plt.xlabel('Total THC [%]')
plt.ylabel('CBD [%]')
plt.title('Amount Total THC vs CBD, corr = -29')
pp.savefig()

# %%
plt.scatter(base_df['THCA'], base_df['CBD'])
fig_size = [7,6]
plt.xlabel('THCA [%]')
plt.ylabel('CBD [%]')
plt.title('Amount THCA vs CBD, corr = -29')
pp.savefig()

# %%
plt.scatter(base_df['CBCA'], base_df['CBG'])
fig_size = [7,6]
plt.xlabel('CBCA [%]')
plt.ylabel('CBG [%]')
plt.title('Amount CBCA vs CBG, corr = 29')
pp.savefig()

# %%
plt.scatter(base_df['Delta-9-THC'], base_df['CBC'])
fig_size = [7,6]
plt.xlabel('Delta-9-THC [%]')
plt.ylabel('CBC [%]')
plt.title('Amount Delta-9-THC vs CBC, corr = 27')
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/Delta-9-CBC.pdf')

# %%
plt.scatter(base_df['CBDA'], base_df['CBC'])
fig_size = [7,6]
plt.xlabel('CBDA [%]')
plt.ylabel('CBC [%]')
plt.title('Amount CBDA vs CBC, corr = 27')
pp.savefig()

# %%
plt.scatter(base_df['Total THC'], base_df['CBC'])
fig_size = [7,6]
plt.xlabel('Total THC [%]')
plt.ylabel('CBC [%]')
plt.title('Amount Total THC vs CBC, corr = 26')
pp.savefig()

# %%
plt.scatter(base_df['Total THC'], base_df['CBDVA'])
fig_size = [7,6]
plt.xlabel('Total THC [%]')
plt.ylabel('CBDVA [%]')
plt.title('Amount Total THC vs CBDVA, corr = 25')
pp.savefig()

# %%
plt.scatter(base_df['CBCA'], base_df['CBC'])
fig_size = [7,6]
plt.xlabel('CBCA [%]')
plt.ylabel('CBC [%]')
plt.title('Amount CBCA vs CBC, corr = 23')
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/CBCA-CBC.pdf')

# %%
plt.scatter(base_df['THCA'], base_df['CBDVA'])
fig_size = [7,6]
plt.xlabel('THCA [%]')
plt.ylabel('CBDVA [%]')
plt.title('Amount THCA vs CBDVA, corr = -23')
pp.savefig()

# %%
plt.scatter(base_df['Total THC'], base_df['THCVA'])
fig_size = [7,6]
plt.xlabel('Total THC [%]')
plt.ylabel('THCVA [%]')
plt.title('Amount Total THC vs THCVA, corr = 20')
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/Total_THC-THCVA.pdf')

# %%
plt.scatter(base_df['CBGA'], base_df['THCVA'])
fig_size = [7,6]
plt.xlabel('CBGA [%]')
plt.ylabel('THCVA [%]')
plt.title('Amount CBGA vs THCVA, corr = 20')
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/CBGA-THCVA.pdf')

# %%
plt.scatter(base_df['THCA'], base_df['THCVA'])
fig_size = [7,6]
plt.xlabel('THCA [%]')
plt.ylabel('THCVA [%]')
plt.title('Amount THCA vs THCVA, corr = 20')
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/THCA-THCVA.pdf')

# %%
plt.scatter(base_df['CBG'], base_df['CBC'])
fig_size = [7,6]
plt.xlabel('CBG [%]')
plt.ylabel('CBC [%]')
plt.title('Amount CBG vs CBC, corr = 20')
pp.savefig()

# %%
plt.scatter(base_df['CBG'], base_df['CBDV'])
fig_size = [7,6]
plt.xlabel('CBG [%]')
plt.ylabel('CBDV [%]')
plt.title('Amount CBG vs CBDV, corr = 20')
pp.savefig()

# %%
plt.scatter(base_df['CBDVA'], base_df['CBCA'])
fig_size = [7,6]
plt.xlabel('CBDVA [%]')
plt.ylabel('CBCA [%]')
plt.title('Amount CBDVA vs CBCA, corr = 19')
pp.savefig()

# %%
plt.scatter(base_df['THCVA'], base_df['CBG'])
fig_size = [7,6]
plt.xlabel('THCVA [%]')
plt.ylabel('CBG [%]')
plt.title('Amount THCVA vs CBG, corr = 17')
pp.savefig()

# %%
plt.scatter(base_df['CBCA'], base_df['CBGA'])
fig_size = [7,6]
plt.xlabel('CBCA [%]')
plt.ylabel('CBGA [%]')
plt.title('Amount CBCA vs CBGA, corr = 16')
pp.savefig()

# %%
plt.scatter(base_df['CBDV'], base_df['CBD'])
fig_size = [7,6]
plt.xlabel('CBDV [%]')
plt.ylabel('CBD [%]')
plt.title('Amount CBDV vs CBD, corr = 15')
pp.savefig()

# %%
plt.scatter(base_df['CBN'], base_df['CBC'])
fig_size = [7,6]
plt.xlabel('CBN [%]')
plt.ylabel('CBC [%]')
plt.title('Amount CBN vs CBC, corr = 15')
pp.savefig()

# %%
plt.scatter(base_df['Delta-9-THC'], base_df['CBG'])
fig_size = [7,6]
plt.xlabel('Delta-9-THC [%]')
plt.ylabel('CBG [%]')
plt.title('Amount Delta-9-THC vs CBG, corr = 15')
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/Delta-9-CBG.pdf')

# %%
plt.scatter(base_df['Total THC'], base_df['CBG'])
fig_size = [7,6]
plt.xlabel('Total THC [%]')
plt.ylabel('CBG [%]')
plt.title('Amount Total THC vs CBG, corr = 15')
pp.savefig()

# %%
plt.scatter(base_df['Total CBD'], base_df['CBDV'])
fig_size = [7,6]
plt.xlabel('Total CBD [%]')
plt.ylabel('CBDV [%]')
plt.title('Amount Total CBD vs CBDV, corr = 14')
pp.savefig()

# %%
plt.scatter(base_df['Total CBD'], base_df['CBGA'])
fig_size = [7,6]
plt.xlabel('Total CBD [%]')
plt.ylabel('CBGA [%]')
plt.title('Amount Total CBD vs CBGA, corr = -14')
pp.savefig()

# %%
plt.scatter(base_df['CBDA'], base_df['CBGA'])
fig_size = [7,6]
plt.xlabel('CBDA [%]')
plt.ylabel('CBGA [%]')
plt.title('Amount CBDA vs CBGA, corr = -13')
pp.savefig()

# %%
plt.scatter(base_df['Delta-9-THC'], base_df['THCA'])
fig_size = [7,6]
plt.xlabel('Delta-9-THC [%]')
plt.ylabel('THCA [%]')
plt.title('Amount Delta-9-THC vs THCA, corr = -13')
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/Delta-9-THCA.pdf')

# %%
plt.scatter(base_df['CBDA'], base_df['CBDV'])
fig_size = [7,6]
plt.xlabel('CBDA [%]')
plt.ylabel('CBDV [%]')
plt.title('Amount CBDA vs CBDV, corr = 12')
pp.savefig()

# %%
plt.scatter(base_df['Delta-9-THC'], base_df['CBDA'])
fig_size = [7,6]
plt.xlabel('Delta-9-THC [%]')
plt.ylabel('CBDA [%]')
plt.title('Amount Delta-9-THC vs CBDA, corr = -12')
pp.savefig()

# %%
plt.scatter(base_df['THCA'], base_df['CBG'])
fig_size = [7,6]
plt.xlabel('THCA [%]')
plt.ylabel('CBG [%]')
plt.title('Amount THCA vs CBG, corr = 12')
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/THCA-CBG.pdf')

# %%
plt.scatter(base_df['CBDVA'], base_df['CBC'])
fig_size = [7,6]
plt.xlabel('CBDVA [%]')
plt.ylabel('CBC [%]')
plt.title('Amount CBDVA vs CBC, corr = 11')
pp.savefig()

# %%
plt.scatter(base_df['CBDVA'], base_df['CBD'])
fig_size = [7,6]
plt.xlabel('CBDVA [%]')
plt.ylabel('CBD [%]')
plt.title('Amount CBDVA vs CBD, corr = 11')
pp.savefig()

# %%
plt.scatter(base_df['CBGA'], base_df['CBD'])
fig_size = [7,6]
plt.xlabel('CBGA [%]')
plt.ylabel('CBD [%]')
plt.title('Amount CBGA vs CBD, corr = -11')
pp.savefig()

# %%
plt.scatter(base_df['THCVA'], base_df['Delta-8-THC'])
fig_size = [7,6]
plt.xlabel('THCVA [%]')
plt.ylabel('Delta-8-THC [%]')
plt.title('Amount THCVA vs Delta-8-THC, corr = 11')
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/THCVA-Delta-8.pdf')

# %%
plt.scatter(base_df['Total CBD'], base_df['Delta-9-THC'])
fig_size = [7,6]
plt.xlabel('Total CBD [%]')
plt.ylabel('Delta-9-THC [%]')
plt.title('Amount Total CBD vs Delta-9-THC, corr = -11')
pp.savefig()

# %%
plt.scatter(base_df['CBCA'], base_df['CBD'])
fig_size = [7,6]
plt.xlabel('CBCA [%]')
plt.ylabel('CBD [%]')
plt.title('Amount CBCA vs CBD, corr = 10')
pp.savefig()

# %%
plt.scatter(base_df['CBCA'], base_df['CBD'])
fig_size = [7,6]
plt.xlabel('CBCA [%]')
plt.ylabel('CBD [%]')
plt.title('Amount CBCA vs CBD, corr = 10')
pp.savefig()

# %%
plt.scatter(base_df['THCA'], base_df['CBN'])
fig_size = [7,6]
plt.xlabel('THCA [%]')
plt.ylabel('CBN [%]')
plt.title('Amount THCA vs CBN, corr = -10')
pp.savefig()

# %%
plt.scatter(base_df['THCVA'], base_df['CBDA'])
fig_size = [7,6]
plt.xlabel('THCVA [%]')
plt.ylabel('CBDA [%]')
plt.title('Amount THCVA vs CBDA, corr = -10')
pp.savefig()

# %%
plt.scatter(base_df['THCVA'], base_df['Total CBD'])
fig_size = [7,6]
plt.xlabel('THCVA [%]')
plt.ylabel('Total CBD [%]')
plt.title('Amount THCVA vs Total CBD, corr = -10')
pp.savefig()

# %%
plt.scatter(base_df['CBGA'], base_df['CBC'])
fig_size = [7,6]
plt.xlabel('CBGA [%]')
plt.ylabel('CBC [%]')
plt.title('Amount CBGA vs Total CBC, corr = -9')
pp.savefig()

# %%
plt.scatter(base_df['CBG'], base_df['CBN'])
fig_size = [7,6]
plt.xlabel('CBG [%]')
plt.ylabel('CBN [%]')
plt.title('Amount CBG vs Total CBN, corr = 9')
pp.savefig()

# %%
plt.scatter(base_df['CBG'], base_df['Total CBD'])
fig_size = [7,6]
plt.xlabel('CBG [%]')
plt.ylabel('Total CBD [%]')
plt.title('Amount CBG vs Total CBD, corr = 9')
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/CBG-Total_CBD.pdf')

# %%
plt.scatter(base_df['CBDV'], base_df['CBCA'])
fig_size = [7,6]
plt.xlabel('CBDV [%]')
plt.ylabel('CBCA [%]')
plt.title('Amount CBDV vs CBCA, corr = 8')
pp.savefig()

# %%
plt.scatter(base_df['CBG'], base_df['CBDA'])
fig_size = [7,6]
plt.xlabel('CBG [%]')
plt.ylabel('CBDA [%]')
plt.title('Amount CBG vs CBDA, corr = 8')
pp.savefig()

# %%
plt.scatter(base_df['CBG'], base_df['CBGA'])
fig_size = [7,6]
plt.xlabel('CBG [%]')
plt.ylabel('CBGA [%]')
plt.title('Amount CBG vs CBGA, corr = 8')
pp.savefig()

# %%
plt.scatter(base_df['Delta-9-THC'], base_df['CBCA'])
fig_size = [7,6]
plt.xlabel('Delta-9-THC [%]')
plt.ylabel('CBCA [%]')
plt.title('Amount Delta-9-THC vs CBCA, corr = -8')
pp.savefig()

# %%
plt.scatter(base_df['CBG'], base_df['CBD'])
fig_size = [7,6]
plt.xlabel('CBG [%]')
plt.ylabel('CBD [%]')
plt.title('Amount CBG vs CBD, corr = 7')
pp.savefig()

# %%
plt.scatter(base_df['Delta-9-THC'], base_df['CBDVA'])
fig_size = [7,6]
plt.xlabel('Delta-9-THC [%]')
plt.ylabel('CBDVA [%]')
plt.title('Amount Delta-9-THC vs CBDVA, corr = -7')
pp.savefig()

# %%
plt.scatter(base_df['THCA'], base_df['Delta-8-THC'])
fig_size = [7,6]
plt.xlabel('THCA [%]')
plt.ylabel('Delta-8-THC [%]')
plt.title('Amount THCA vs Delta-8-THC, corr = 7')
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/THCA-Delta-8.pdf')

# %%
plt.scatter(base_df['THCVA'], base_df['CBCA'])
fig_size = [7,6]
plt.xlabel('THCVA [%]')
plt.ylabel('CBCA [%]')
plt.title('Amount THCVA vs CBCA, corr = 7')
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/CBCA-THCVA.pdf')

# %%
plt.scatter(base_df['CBG'], base_df['Delta-8-THC'])
fig_size = [7,6]
plt.xlabel('CBG [%]')
plt.ylabel('Delta-8-THC [%]')
plt.title('Amount CBG vs Delta-8-THC, corr = 6')
pp.savefig()

# %%
plt.scatter(base_df['CBGA'], base_df['Delta-9-THC'])
fig_size = [7,6]
plt.xlabel('CBGA [%]')
plt.ylabel('Delta-9-THC [%]')
plt.title('Amount CBGA vs Delta-9-THC, corr = -6')
pp.savefig()

# %%
plt.scatter(base_df['THCA'], base_df['CBDV'])
fig_size = [7,6]
plt.xlabel('THCA [%]')
plt.ylabel('CBDV [%]')
plt.title('Amount THCA vs CBDV, corr = -6')
pp.savefig()

# %%
plt.scatter(base_df['THCVA'], base_df['CBD'])
fig_size = [7,6]
plt.xlabel('THCVA [%]')
plt.ylabel('CBD [%]')
plt.title('Amount THCVA vs CBD, corr = -6')
pp.savefig()

# %%
plt.scatter(base_df['Total THC'], base_df['CBDV'])
fig_size = [7,6]
plt.xlabel('Total THC [%]')
plt.ylabel('CBDV [%]')
plt.title('Amount Total THC vs CBDV, corr = -6')
pp.savefig()

# %%
plt.scatter(base_df['Total THC'], base_df['Delta-8-THC'])
fig_size = [7,6]
plt.xlabel('Total THC [%]')
plt.ylabel('Delta-8-THC [%]')
plt.title('Amount Total THC vs Delta-8-THC, corr = 6')
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/Total_THC-Delta-8.pdf')

# %%
plt.scatter(base_df['Total THC'], base_df['Delta-9-THC'])
fig_size = [7,6]
plt.xlabel('Total THC [%]')
plt.ylabel('Delta-9-THC [%]')
plt.title('Amount Total THC vs Delta-9-THC, corr = 6')
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/Total_THC-Delta-9.pdf')

# %%
plt.scatter(base_df['CBG'], base_df['CBDVA'])
fig_size = [7,6]
plt.xlabel('CBG [%]')
plt.ylabel('CBDVA [%]')
plt.title('Amount CBG vs CBDVA, corr = 5')
pp.savefig()

# %%
plt.scatter(base_df['CBGA'], base_df['CBN'])
fig_size = [7,6]
plt.xlabel('CBGA [%]')
plt.ylabel('CBN [%]')
plt.title('Amount CBGA vs CBN, corr = -5')
pp.savefig()

# %%
plt.scatter(base_df['CBDV'], base_df['CBDVA'])
fig_size = [7,6]
plt.xlabel('CBDV [%]')
plt.ylabel('CBDVA [%]')
plt.title('Amount CBDV vs CBDVA, corr = 4')
pp.savefig()

# %%
plt.scatter(base_df['CBC'], base_df['THCVA'])
fig_size = [7,6]
plt.xlabel('CBC [%]')
plt.ylabel('THCVA [%]')
plt.title('Amount CBC vs THCVA, corr = -4')
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/CBC-THCVA.pdf')

# %%
plt.scatter(base_df['Total THC'], base_df['CBCA'])
fig_size = [7,6]
plt.xlabel('Total THC [%]')
plt.ylabel('CBCA [%]')
plt.title('Amount Total THC vs CBCA, corr = 4')
pp.savefig()
plt.savefig('./pdfs/canna_flower_plts/Total_THC-CBCA.pdf')

# %%
plt.scatter(base_df['CBN'], base_df['CBCA'])
fig_size = [7,6]
plt.xlabel('CBN [%]')
plt.ylabel('CBCA [%]')
plt.title('Amount CBN vs CBCA, corr = -3')
pp.savefig()

# %%
plt.scatter(base_df['Delta-8-THC'], base_df['CBCA'])
fig_size = [7,6]
plt.xlabel('Delta-8-THC [%]')
plt.ylabel('CBCA [%]')
plt.title('Amount Delta-8-THC vs CBCA, corr = 3')
pp.savefig()

# %%
plt.scatter(base_df['Delta-9-THC'], base_df['THCV'])
fig_size = [7,6]
plt.xlabel('Delta-9-THC [%]')
plt.ylabel('THCV [%]')
plt.title('Amount Delta-9-THC vs THCV, corr = 3')
pp.savefig()

# %%
plt.scatter(base_df['CBN'], base_df['THCVA'])
fig_size = [7,6]
plt.xlabel('CBN [%]')
plt.ylabel('THCVA [%]')
plt.title('Amount CBN vs THCVA, corr = 3')
pp.savefig()

# %%
plt.scatter(base_df['Total THC'], base_df['CBN'])
fig_size = [7,6]
plt.xlabel('Total THC [%]')
plt.ylabel('CBN [%]')
plt.title('Amount Total THC vs CBN, corr = -3')
pp.savefig()

# %%
plt.scatter(base_df['CBGA'], base_df['CBDVA'])
fig_size = [7,6]
plt.xlabel('CBGA [%]')
plt.ylabel('CBDVA [%]')
plt.title('Amount CBGA vs CBDVA, corr = -2')
pp.savefig()

# %%
plt.scatter(base_df['CBN'], base_df['CBD'])
fig_size = [7,6]
plt.xlabel('CBN [%]')
plt.ylabel('CBD [%]')
plt.title('Amount CBN vs CBD, corr = 2')
pp.savefig()

# %%
plt.scatter(base_df['Delta-8-THC'], base_df['CBDA'])
fig_size = [7,6]
plt.xlabel('Delta-8-THC [%]')
plt.ylabel('CBDA [%]')
plt.title('Amount Delta-8-THC vs CBDA, corr = -2')
pp.savefig()

# %%
plt.scatter(base_df['Delta-8-THC'], base_df['CBGA'])
fig_size = [7,6]
plt.xlabel('Delta-8-THC [%]')
plt.ylabel('CBGA [%]')
plt.title('Amount Delta-8-THC vs CBDA, corr = 2')
pp.savefig()

# %%
plt.scatter(base_df['Delta-8-THC'], base_df['Delta-9-THC'])
fig_size = [7,6]
plt.xlabel('Delta-8-THC [%]')
plt.ylabel('Delta-9-THC [%]')
plt.title('Amount Delta-8-THC vs Delta-9-THC, corr = -2')
pp.savefig()

# %%
plt.scatter(base_df['THCA'], base_df['CBCA'])
fig_size = [7,6]
plt.xlabel('THCA [%]')
plt.ylabel('CBCA [%]')
plt.title('Amount THCA vs CBCA, corr = -2')
pp.savefig()

# %%
plt.scatter(base_df['Delta-8-THC'], base_df['Total CBD'])
fig_size = [7,6]
plt.xlabel('Delta-8-THC [%]')
plt.ylabel('Total CBD [%]')
plt.title('Delta-8-THC vs Total CBD, corr = -2')
pp.savefig()

# %%
plt.scatter(base_df['CBN'], base_df['Total CBD'])
fig_size = [7,6]
plt.xlabel('CBN [%]')
plt.ylabel('Total CBD [%]')
plt.title('CBN vs Total CBD, corr = -1')
pp.savefig()

# %%
plt.scatter(base_df['THCV'], base_df['Total CBD'])
fig_size = [7,6]
plt.xlabel('THCV [%]')
plt.ylabel('Total CBD [%]')
plt.title('THCV vs Total CBD, corr = -1')
pp.savefig()

# %%
plt.scatter(base_df['THCV'], base_df['THCVA'])
fig_size = [7,6]
plt.xlabel('THCV [%]')
plt.ylabel('THCVA [%]')
plt.title('Amount THCV vs THCVA, corr = 1')
pp.savefig()

# %%
plt.scatter(base_df['CBDVA'], base_df['THCVA'])
fig_size = [7,6]
plt.xlabel('CBDVA [%]')
plt.ylabel('THCVA [%]')
plt.title('Amount CBDVA vs THCVA, corr = -1')
pp.savefig()

# %%
plt.scatter(base_df['THCV'], base_df['CBC'])
fig_size = [7,6]
plt.xlabel('THCV [%]')
plt.ylabel('CBC [%]')
plt.title('Amount THCV vs CBC, corr = 1')
pp.savefig()

# %%
plt.scatter(base_df['THCV'], base_df['CBCA'])
fig_size = [7,6]
plt.xlabel('THCV [%]')
plt.ylabel('CBCA [%]')
plt.title('Amount THCV vs CBCA, corr = 1')
pp.savefig()

# %%
plt.scatter(base_df['THCV'], base_df['CBDA'])
fig_size = [7,6]
plt.xlabel('THCV [%]')
plt.ylabel('CBDA [%]')
plt.title('Amount THCV vs CBDA, corr = -1')
pp.savefig()

# %%
plt.scatter(base_df['THCV'], base_df['CBDVA'])
fig_size = [7,6]
plt.xlabel('THCV [%]')
plt.ylabel('CBDVA [%]')
plt.title('Amount THCV vs CBDVA, corr = -1')
pp.savefig()

# %%
plt.scatter(base_df['THCV'], base_df['CBG'])
fig_size = [7,6]
plt.xlabel('THCV [%]')
plt.ylabel('CBG [%]')
plt.title('Amount THCV vs CBG, corr = -1')
pp.savefig()

# %%
plt.scatter(base_df['THCV'], base_df['CBGA'])
fig_size = [7,6]
plt.xlabel('THCV [%]')
plt.ylabel('CBGA [%]')
plt.title('Amount THCV vs CBGA, corr = -1')
pp.savefig()

# %%
plt.scatter(base_df['THCV'], base_df['Delta-8-THC'])
fig_size = [7,6]
plt.xlabel('THCV [%]')
plt.ylabel('Delta-8-THC [%]')
plt.title('Amount THCV vs Delta-8-THC, corr = 1')
pp.savefig()

# %%
plt.scatter(base_df['THCV'], base_df['THCA'])
fig_size = [7,6]
plt.xlabel('THCV [%]')
plt.ylabel('THCA [%]')
plt.title('Amount THCV vs THCA, corr = -1')
pp.savefig()

# %%
plt.scatter(base_df['Delta-9-THC'], base_df['CBD'])
fig_size = [7,6]
plt.xlabel('Delta-9-THC [%]')
plt.ylabel('CBD [%]')
plt.title('Amount Delta-9-THC vs CBD, corr = 1')
pp.savefig()

# %%
plt.scatter(base_df['Delta-8-THC'], base_df['CBN'])
fig_size = [7,6]
plt.xlabel('Delta-8-THC [%]')
plt.ylabel('CBN [%]')
plt.title('Amount Delta-8-THC vs CBN, corr = -1')
pp.savefig()

# %%
plt.scatter(base_df['Delta-8-THC'], base_df['CBDV'])
fig_size = [7,6]
plt.xlabel('Delta-8-THC [%]')
plt.ylabel('CBDV [%]')
plt.title('Amount Delta-8-THC vs CBDV, corr = -1')
pp.savefig()

# %%
plt.scatter(base_df['Delta-8-THC'], base_df['CBD'])
fig_size = [7,6]
plt.xlabel('Delta-8-THC [%]')
plt.ylabel('CBD [%]')
plt.title('Amount Delta-8-THC vs CBD, corr = -1')
pp.savefig()

# %%
plt.scatter(base_df['CBDA'], base_df['CBN'])
fig_size = [7,6]
plt.xlabel('CBDA [%]')
plt.ylabel('CBN [%]')
plt.title('Amount CBDA vs CBN, corr = -1')
pp.savefig()

# %%
plt.scatter(base_df['CBDVA'], base_df['CBN'])
fig_size = [7,6]
plt.xlabel('CBDVA [%]')
plt.ylabel('CBN [%]')
plt.title('Amount CBDVA vs CBN, corr = -1')
pp.savefig()

# %%
plt.scatter(base_df['CBGA'], base_df['CBDV'])
fig_size = [7,6]
plt.xlabel('CBGA [%]')
plt.ylabel('CBDV [%]')
plt.title('Amount CBGA vs CBDV, corr = 0')
pp.savefig()

# %%
plt.scatter(base_df['CBDV'], base_df['CBN'])
fig_size = [7,6]
plt.xlabel('CBDV [%]')
plt.ylabel('CBN [%]')
plt.title('Amount CBDV vs CBN, corr = 0')
pp.savefig()

# %%
plt.scatter(base_df['Delta-8-THC'], base_df['CBC'])
fig_size = [7,6]
plt.xlabel('Delta-8-THC [%]')
plt.ylabel('CBC [%]')
plt.title('Amount Delta-8-THC vs CBC, corr = 0')
pp.savefig()

# %%
plt.scatter(base_df['Delta-8-THC'], base_df['CBDVA'])
fig_size = [7,6]
plt.xlabel('Delta-8-THC [%]')
plt.ylabel('CBDVA [%]')
plt.title('Amount Delta-8-THC vs CBDVA, corr = 0')
pp.savefig()

# %%
plt.scatter(base_df['Delta-9-THC'], base_df['CBDV'])
fig_size = [7,6]
plt.xlabel('Delta-9-THC [%]')
plt.ylabel('CBDV [%]')
plt.title('Amount Delta-9-THC vs CBDV, corr = 0')
pp.savefig()

# %%
plt.scatter(base_df['THCV'], base_df['CBD'])
fig_size = [7,6]
plt.xlabel('THCV [%]')
plt.ylabel('CBD [%]')
plt.title('Amount THCV vs CBD, corr = 0')
pp.savefig()

# %%
plt.scatter(base_df['THCV'], base_df['CBDV'])
fig_size = [7,6]
plt.xlabel('THCV [%]')
plt.ylabel('CBDV [%]')
plt.title('Amount THCV vs CBDV, corr = 0')
pp.savefig()

# %%
plt.scatter(base_df['THCV'], base_df['CBN'])
fig_size = [7,6]
plt.xlabel('THCV [%]')
plt.ylabel('CBN [%]')
plt.title('Amount THCV vs CBN, corr = 0')
pp.savefig()

# %%
plt.scatter(base_df['THCV'], base_df['Total THC'])
fig_size = [7,6]
plt.xlabel('THCV [%]')
plt.ylabel('Total THC [%]')
plt.title('Amount THCV vs Total THC, corr = 0')
pp.savefig()

# %%
plt.scatter(base_df['THCVA'], base_df['CBDV'])
fig_size = [7,6]
plt.xlabel('THCVA [%]')
plt.ylabel('CBDV [%]')
plt.title('Amount THCVA vs CBDV, corr = 0')
pp.savefig()

# %%
plt.scatter(base_df['THCVA'], base_df['Delta-9-THC'])
fig_size = [7,6]
plt.xlabel('THCVA [%]')
plt.ylabel('Delta-9-THC [%]')
plt.title('Amount THCVA vs Delta-9-THC, corr = 0')
pp.savefig()

# %%
pp.close()
